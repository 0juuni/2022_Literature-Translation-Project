# %%
# https://wikidocs.net/86900 참고

import numpy as np
import matplotlib.pyplot as plt
import unicodedata
import re
import io

import tensorflow as tf
from tensorflow.keras import preprocessing
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Masking
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = "/content/drive/MyDrive/관동별곡.txt"

# %%
# 유니코드 파일을 아스키 코드 파일로 변환합니다.
def unicode_to_ascii(s):
  return ''.join(c for c in unicodedata.normalize('NFD', s)
      if unicodedata.category(c) != 'Mn')


def preprocess_sentence(w):
  w = unicode_to_ascii(w.lower().strip())

  # 단어와 단어 뒤에 오는 구두점(.)사이에 공백을 생성합니다. 
  w = re.sub(r"([?.!,¿])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # (a-z, A-Z, ".", "?", "!", ",")을 제외한 모든 것을 공백으로 대체합니다.
  w = re.sub(r"['ㅣ가-힣?.!,]+", r" ", w)

  w = w.strip() # 문장 양 끝의 공백 제거

  # # 모델이 예측을 시작하거나 중단할 때를 알게 하기 위해서
  # # 문장에 start와 end 토큰을 추가합니다.
  # w = '<start> ' + w + ' <end>'
  return w

def decoder_preprocess(seq):
  decoder_in = []
  decoder_out = []
  # 모델이 예측을 시작하거나 중단할 때를 알게 하기 위해서
  # 문장에 start와 end 토큰을 추가합니다.
  for w in seq:
    decoder_in.append('<start> ' + w)
    decoder_out.append(w + ' <end>')
  return tuple(decoder_in), tuple(decoder_out)

# %%
def create_dataset(file_path, num_examples):
  lines = io.open(file_path, encoding='UTF-8').read().strip().split('\n')
  word_pairs = [[preprocess_sentence(w) for w in l.split('|')]  for l in lines[:num_examples]]
  return zip(*word_pairs)

# %%
ko, ko2 = create_dataset(file_path, None)
ko2_1, ko2_2 = decoder_preprocess(ko2)
print(ko[-1])
print(ko2_1[-1])
print(ko2_2[-1])
# Out:
# 명월이 천산만낙의 아니비쵠ᄃᆡ 업다
# <start> 밝은 달이 온 세상에 아니 비친 곳 없다
# 밝은 달이 온 세상에 아니 비친 곳 없다 <end>

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)
  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor, padding='post')

  return tensor, lang_tokenizer

def tokenize_dec(lang):
  lang1, lang2 = decoder_preprocess(lang)

  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
  lang_tokenizer.fit_on_texts(lang1)
  lang_tokenizer.fit_on_texts(lang2)

  tensor_in = lang_tokenizer.texts_to_sequences(lang1)
  tensor_in = tf.keras.preprocessing.sequence.pad_sequences(tensor_in, padding='post')

  tensor_out = lang_tokenizer.texts_to_sequences(lang2)
  tensor_out = tf.keras.preprocessing.sequence.pad_sequences(tensor_out, padding='post')

  return tensor_in, tensor_out, lang_tokenizer

# %%
def load_dataset(file_path, num_examples=None):
  # 전처리된 타겟 문장과 입력 문장 쌍을 생성합니다.
  inp_lang, targ_lang = create_dataset(file_path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_in_tensor, target_out_tensor, targ_lang_tokenizer = tokenize_dec(targ_lang)

  return input_tensor, target_in_tensor, target_out_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %%
# 언어 데이터셋을 아래의 크기로 제한하여 훈련과 검증을 수행합니다.
num_examples = 30000
input_tensor, target_in_tensor, target_out_tensor, inp_lang, targ_lang = load_dataset(file_path, num_examples)

# 타겟 텐서와 입력 텐서의 최대 길이를 계산합니다.
max_length_targ, max_length_inp = target_in_tensor.shape[1], input_tensor.shape[1]

# %%
input_tensor[0]
# Out:
# array([22, 23, 24, 25,  0,  0,  0,  0], dtype=int32)

# %%
target_in_tensor[0:5]
# Out:
# array([[ 1, 70, 71, 72, 73, 74,  0,  0,  0,  0],
#        [ 1, 75, 76, 77, 78, 79,  0,  0,  0,  0],
#        [ 1,  9, 80, 81, 82,  0,  0,  0,  0,  0],
#        [ 1, 83, 84, 85, 86, 24,  0,  0,  0,  0],
#        [ 1, 87, 88, 89, 25, 90,  0,  0,  0,  0]], dtype=int32)

# %%
target_out_tensor[0:5]
# Out:
# array([[70, 71, 72, 73, 74,  2,  0,  0,  0,  0],
#        [75, 76, 77, 78, 79,  2,  0,  0,  0,  0],
#        [ 9, 80, 81, 82,  2,  0,  0,  0,  0,  0],
#        [83, 84, 85, 86, 24,  2,  0,  0,  0,  0],
#        [87, 88, 89, 25, 90,  2,  0,  0,  0,  0]], dtype=int32)

# %%
n_of_val = int(len(input_tensor)*0.2)
print('학습 데이터의 개수 :',len(input_tensor)-n_of_val)
print('검증 데이터의 개수 :',n_of_val)

# 훈련 집합과 검증 집합을 80대 20으로 분리합니다.
input_tensor_train, input_tensor_val = input_tensor[:-n_of_val], input_tensor[-n_of_val:]
target_in_tensor_train, target_in_tensor_val = target_in_tensor[:-n_of_val], target_in_tensor[-n_of_val:]
target_out_tensor_train, target_out_tensor_val = target_out_tensor[:-n_of_val], target_out_tensor[-n_of_val:]
# Out:
# 학습 데이터의 개수 : 116
# 검증 데이터의 개수 : 29

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target input Language; index to word mapping")
convert(targ_lang, target_in_tensor_train[0])
print ()
print ("Target output Language; index to word mapping")
convert(targ_lang, target_out_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 22 ----> 강호에
# 23 ----> 병이깁퍼
# 24 ----> 듁님의
# 25 ----> 누엇더니
#
# Target input Language; index to word mapping
# 1 ----> <start>
# 70 ----> 강호에
# 71 ----> 병이
# 72 ----> 깊어
# 73 ----> 대숲에
# 74 ----> 누었더니
#
# Target output Language; index to word mapping
# 70 ----> 강호에
# 71 ----> 병이
# 72 ----> 깊어
# 73 ----> 대숲에
# 74 ----> 누었더니
# 2 ----> <end>

# %%
print(input_tensor_train.shape, input_tensor_val.shape)
print(target_in_tensor_train.shape, target_in_tensor_val.shape)
print(target_out_tensor_train.shape, target_out_tensor_val.shape)
# Out:
# (116, 8) (29, 8)
# (116, 10) (29, 10)
# (116, 10) (29, 10)

# %%
in_vocab_size = len(inp_lang.word_index) + 1
tar_vocab_size = len(targ_lang.word_index) + 1
print("고전문학 단어 집합의 크기 : {:d}, 현대어 단어 집합의 크기 : {:d}".format(in_vocab_size, tar_vocab_size))
# Out:
# 고전문학 단어 집합의 크기 : 577, 현대어 단어 집합의 크기 : 656

# %%
embedding_dim = 64
hidden_units = 64

# %%
# 인코더
encoder_inputs = Input(shape=(None,))
enc_emb = Embedding(in_vocab_size, embedding_dim)(encoder_inputs) # 임베딩 층
enc_masking = Masking(mask_value=0.0)(enc_emb) # 패딩 0은 연산에서 제외
encoder_lstm = LSTM(hidden_units, return_state=True) # 상태값 리턴을 위해 return_state는 True
encoder_outputs, state_h, state_c = encoder_lstm(enc_masking) # 은닉 상태와 셀 상태를 리턴
encoder_states = [state_h, state_c] # 인코더의 은닉 상태와 셀 상태를 저장

# %%
# 디코더
decoder_inputs = Input(shape=(None,))
dec_emb_layer = Embedding(tar_vocab_size, hidden_units) # 임베딩 층
dec_emb = dec_emb_layer(decoder_inputs) # 패딩 0은 연산에서 제외
dec_masking = Masking(mask_value=0.0)(dec_emb)

# 상태값 리턴을 위해 return_state는 True, 모든 시점에 대해서 단어를 예측하기 위해 return_sequences는 True
decoder_lstm = LSTM(hidden_units, return_sequences=True, return_state=True) 

# 인코더의 은닉 상태를 초기 은닉 상태(initial_state)로 사용
decoder_outputs, _, _ = decoder_lstm(dec_masking, initial_state=encoder_states)

# 모든 시점의 결과에 대해서 소프트맥스 함수를 사용한 출력층을 통해 단어 예측
decoder_dense = Dense(tar_vocab_size, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# 모델의 입력과 출력을 정의.
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])

# %%
his = model.fit(x=[input_tensor_train, target_in_tensor_train], y=target_out_tensor_train, \
          validation_data=([input_tensor_val, target_in_tensor_val], target_out_tensor_val),
          batch_size=16, epochs=300)
# Out:
# Epoch 1/300
# 8/8 [==============================] - 13s 460ms/step - loss: 6.4692 - acc: 0.3129 - val_loss: 6.4501 - val_acc: 0.3000
# Epoch 2/300
# 8/8 [==============================] - 0s 27ms/step - loss: 6.3830 - acc: 0.3897 - val_loss: 6.3128 - val_acc: 0.3000
# Epoch 3/300
# 8/8 [==============================] - 0s 32ms/step - loss: 5.9424 - acc: 0.3897 - val_loss: 5.6339 - val_acc: 0.3000
# Epoch 4/300
# 8/8 [==============================] - 0s 27ms/step - loss: 4.9696 - acc: 0.3897 - val_loss: 5.1827 - val_acc: 0.3000
# Epoch 5/300
# 8/8 [==============================] - 0s 27ms/step - loss: 4.3505 - acc: 0.3897 - val_loss: 5.0813 - val_acc: 0.3000
# Epoch 6/300
# 8/8 [==============================] - 0s 28ms/step - loss: 4.0623 - acc: 0.3897 - val_loss: 5.1867 - val_acc: 0.3000
# Epoch 7/300
# 8/8 [==============================] - 0s 29ms/step - loss: 3.9409 - acc: 0.3897 - val_loss: 5.2080 - val_acc: 0.3000
# Epoch 8/300
# 8/8 [==============================] - 0s 28ms/step - loss: 3.8300 - acc: 0.3897 - val_loss: 5.0504 - val_acc: 0.3000
# Epoch 9/300
# 8/8 [==============================] - 0s 29ms/step - loss: 3.7345 - acc: 0.3897 - val_loss: 4.8509 - val_acc: 0.3000
# Epoch 10/300
# 8/8 [==============================] - 0s 27ms/step - loss: 3.6706 - acc: 0.3897 - val_loss: 4.8247 - val_acc: 0.3000
# Epoch 11/300
# 8/8 [==============================] - 0s 28ms/step - loss: 3.6232 - acc: 0.3897 - val_loss: 4.8465 - val_acc: 0.3000
# Epoch 12/300
# 8/8 [==============================] - 0s 29ms/step - loss: 3.5876 - acc: 0.3897 - val_loss: 4.7620 - val_acc: 0.3000
# Epoch 13/300
# 8/8 [==============================] - 0s 26ms/step - loss: 3.5541 - acc: 0.3897 - val_loss: 4.7895 - val_acc: 0.3000
# Epoch 14/300
# 8/8 [==============================] - 0s 27ms/step - loss: 3.5223 - acc: 0.3897 - val_loss: 4.8051 - val_acc: 0.3000
# Epoch 15/300
# 8/8 [==============================] - 0s 28ms/step - loss: 3.4930 - acc: 0.3897 - val_loss: 4.7834 - val_acc: 0.3000
# Epoch 16/300
# 8/8 [==============================] - 0s 28ms/step - loss: 3.4697 - acc: 0.3897 - val_loss: 4.8249 - val_acc: 0.3000
# Epoch 17/300
# 8/8 [==============================] - 0s 27ms/step - loss: 3.4474 - acc: 0.3897 - val_loss: 4.8911 - val_acc: 0.3000
# Epoch 18/300
# 8/8 [==============================] - 0s 27ms/step - loss: 3.4275 - acc: 0.3897 - val_loss: 4.8855 - val_acc: 0.3000
# Epoch 19/300
# 8/8 [==============================] - 0s 26ms/step - loss: 3.4079 - acc: 0.3897 - val_loss: 4.9498 - val_acc: 0.3000
# Epoch 20/300
# 8/8 [==============================] - 0s 27ms/step - loss: 3.3891 - acc: 0.3905 - val_loss: 5.0187 - val_acc: 0.3000
# Epoch 21/300
# 8/8 [==============================] - 0s 30ms/step - loss: 3.3718 - acc: 0.3948 - val_loss: 5.0209 - val_acc: 0.3034
# Epoch 22/300
# 8/8 [==============================] - 0s 26ms/step - loss: 3.3525 - acc: 0.4034 - val_loss: 5.0024 - val_acc: 0.3138
# Epoch 23/300
# 8/8 [==============================] - 0s 26ms/step - loss: 3.3345 - acc: 0.4293 - val_loss: 4.9990 - val_acc: 0.3276
# Epoch 24/300
# 8/8 [==============================] - 0s 26ms/step - loss: 3.3160 - acc: 0.4474 - val_loss: 4.9998 - val_acc: 0.3414
# Epoch 25/300
# 8/8 [==============================] - 0s 26ms/step - loss: 3.2980 - acc: 0.4759 - val_loss: 5.0524 - val_acc: 0.3414
# Epoch 26/300
# 8/8 [==============================] - 0s 26ms/step - loss: 3.2821 - acc: 0.4819 - val_loss: 5.1128 - val_acc: 0.3414
# Epoch 27/300
# 8/8 [==============================] - 0s 27ms/step - loss: 3.2642 - acc: 0.4888 - val_loss: 5.1197 - val_acc: 0.3448
# Epoch 28/300
# 8/8 [==============================] - 0s 29ms/step - loss: 3.2479 - acc: 0.4922 - val_loss: 5.1475 - val_acc: 0.3483
# Epoch 29/300
# 8/8 [==============================] - 0s 27ms/step - loss: 3.2308 - acc: 0.4922 - val_loss: 5.2112 - val_acc: 0.3448
# Epoch 30/300
# 8/8 [==============================] - 0s 28ms/step - loss: 3.2200 - acc: 0.4897 - val_loss: 5.1428 - val_acc: 0.3552
# Epoch 31/300
# 8/8 [==============================] - 0s 26ms/step - loss: 3.2162 - acc: 0.4905 - val_loss: 5.1108 - val_acc: 0.3621
# Epoch 32/300
# 8/8 [==============================] - 0s 27ms/step - loss: 3.1984 - acc: 0.4905 - val_loss: 5.1499 - val_acc: 0.3621
# Epoch 33/300
# 8/8 [==============================] - 0s 26ms/step - loss: 3.1854 - acc: 0.4897 - val_loss: 5.2385 - val_acc: 0.3621
# Epoch 34/300
# 8/8 [==============================] - 0s 26ms/step - loss: 3.1612 - acc: 0.4931 - val_loss: 5.3333 - val_acc: 0.3586
# Epoch 35/300
# 8/8 [==============================] - 0s 27ms/step - loss: 3.1444 - acc: 0.4931 - val_loss: 5.2978 - val_acc: 0.3621
# Epoch 36/300
# 8/8 [==============================] - 0s 25ms/step - loss: 3.1276 - acc: 0.4931 - val_loss: 5.2997 - val_acc: 0.3621
# Epoch 37/300
# 8/8 [==============================] - 0s 26ms/step - loss: 3.1117 - acc: 0.4931 - val_loss: 5.3436 - val_acc: 0.3621
# Epoch 38/300
# 8/8 [==============================] - 0s 25ms/step - loss: 3.0947 - acc: 0.4931 - val_loss: 5.3662 - val_acc: 0.3621
# Epoch 39/300
# 8/8 [==============================] - 0s 26ms/step - loss: 3.0791 - acc: 0.4931 - val_loss: 5.3968 - val_acc: 0.3621
# Epoch 40/300
# 8/8 [==============================] - 0s 28ms/step - loss: 3.0633 - acc: 0.4931 - val_loss: 5.4557 - val_acc: 0.3621
# Epoch 41/300
# 8/8 [==============================] - 0s 27ms/step - loss: 3.0458 - acc: 0.4931 - val_loss: 5.4813 - val_acc: 0.3621
# Epoch 42/300
# 8/8 [==============================] - 0s 27ms/step - loss: 3.0292 - acc: 0.4931 - val_loss: 5.5127 - val_acc: 0.3621
# Epoch 43/300
# 8/8 [==============================] - 0s 27ms/step - loss: 3.0119 - acc: 0.4931 - val_loss: 5.5546 - val_acc: 0.3621
# Epoch 44/300
# 8/8 [==============================] - 0s 27ms/step - loss: 2.9944 - acc: 0.4948 - val_loss: 5.5960 - val_acc: 0.3690
# Epoch 45/300
# 8/8 [==============================] - 0s 28ms/step - loss: 2.9764 - acc: 0.4974 - val_loss: 5.6004 - val_acc: 0.3724
# Epoch 46/300
# 8/8 [==============================] - 0s 26ms/step - loss: 2.9596 - acc: 0.4974 - val_loss: 5.5968 - val_acc: 0.3759
# Epoch 47/300
# 8/8 [==============================] - 0s 27ms/step - loss: 2.9417 - acc: 0.4966 - val_loss: 5.6927 - val_acc: 0.3690
# Epoch 48/300
# 8/8 [==============================] - 0s 26ms/step - loss: 2.9248 - acc: 0.4948 - val_loss: 5.6589 - val_acc: 0.3759
# Epoch 49/300
# 8/8 [==============================] - 0s 28ms/step - loss: 2.9056 - acc: 0.4940 - val_loss: 5.7069 - val_acc: 0.3759
# Epoch 50/300
# 8/8 [==============================] - 0s 26ms/step - loss: 2.8897 - acc: 0.4983 - val_loss: 5.7516 - val_acc: 0.3793
# Epoch 51/300
# 8/8 [==============================] - 0s 27ms/step - loss: 2.8714 - acc: 0.4983 - val_loss: 5.7530 - val_acc: 0.3793
# Epoch 52/300
# 8/8 [==============================] - 0s 27ms/step - loss: 2.8536 - acc: 0.4974 - val_loss: 5.7353 - val_acc: 0.3793
# Epoch 53/300
# 8/8 [==============================] - 0s 28ms/step - loss: 2.8365 - acc: 0.4974 - val_loss: 5.8061 - val_acc: 0.3793
# Epoch 54/300
# 8/8 [==============================] - 0s 28ms/step - loss: 2.8180 - acc: 0.4974 - val_loss: 5.7743 - val_acc: 0.3793
# Epoch 55/300
# 8/8 [==============================] - 0s 26ms/step - loss: 2.7984 - acc: 0.4983 - val_loss: 5.8492 - val_acc: 0.3793
# Epoch 56/300
# 8/8 [==============================] - 0s 27ms/step - loss: 2.7805 - acc: 0.4991 - val_loss: 5.8019 - val_acc: 0.3793
# Epoch 57/300
# 8/8 [==============================] - 0s 26ms/step - loss: 2.7609 - acc: 0.5009 - val_loss: 5.9211 - val_acc: 0.3793
# Epoch 58/300
# 8/8 [==============================] - 0s 29ms/step - loss: 2.7403 - acc: 0.4991 - val_loss: 5.7857 - val_acc: 0.3897
# Epoch 59/300
# 8/8 [==============================] - 0s 27ms/step - loss: 2.7231 - acc: 0.5017 - val_loss: 5.9885 - val_acc: 0.3793
# Epoch 60/300
# 8/8 [==============================] - 0s 26ms/step - loss: 2.7027 - acc: 0.5034 - val_loss: 5.8129 - val_acc: 0.3966
# Epoch 61/300
# 8/8 [==============================] - 0s 27ms/step - loss: 2.6837 - acc: 0.5026 - val_loss: 5.9076 - val_acc: 0.3931
# Epoch 62/300
# 8/8 [==============================] - 0s 26ms/step - loss: 2.6631 - acc: 0.5043 - val_loss: 6.0839 - val_acc: 0.3793
# Epoch 63/300
# 8/8 [==============================] - 0s 27ms/step - loss: 2.6438 - acc: 0.5043 - val_loss: 6.0354 - val_acc: 0.3862
# Epoch 64/300
# 8/8 [==============================] - 0s 27ms/step - loss: 2.6228 - acc: 0.5034 - val_loss: 6.0108 - val_acc: 0.3966
# Epoch 65/300
# 8/8 [==============================] - 0s 26ms/step - loss: 2.6004 - acc: 0.5052 - val_loss: 5.9326 - val_acc: 0.4000
# Epoch 66/300
# 8/8 [==============================] - 0s 25ms/step - loss: 2.5774 - acc: 0.5086 - val_loss: 6.0579 - val_acc: 0.4000
# Epoch 67/300
# 8/8 [==============================] - 0s 26ms/step - loss: 2.5561 - acc: 0.5069 - val_loss: 6.0522 - val_acc: 0.4000
# Epoch 68/300
# 8/8 [==============================] - 0s 29ms/step - loss: 2.5334 - acc: 0.5103 - val_loss: 6.0447 - val_acc: 0.4000
# Epoch 69/300
# 8/8 [==============================] - 0s 26ms/step - loss: 2.5110 - acc: 0.5103 - val_loss: 6.0973 - val_acc: 0.4000
# Epoch 70/300
# 8/8 [==============================] - 0s 27ms/step - loss: 2.4880 - acc: 0.5147 - val_loss: 6.1040 - val_acc: 0.4000
# Epoch 71/300
# 8/8 [==============================] - 0s 25ms/step - loss: 2.4638 - acc: 0.5121 - val_loss: 6.1163 - val_acc: 0.4000
# Epoch 72/300
# 8/8 [==============================] - 0s 26ms/step - loss: 2.4403 - acc: 0.5155 - val_loss: 6.1463 - val_acc: 0.4000
# Epoch 73/300
# 8/8 [==============================] - 0s 27ms/step - loss: 2.4188 - acc: 0.5198 - val_loss: 6.2114 - val_acc: 0.4000
# Epoch 74/300
# 8/8 [==============================] - 0s 27ms/step - loss: 2.3957 - acc: 0.5207 - val_loss: 6.2933 - val_acc: 0.4000
# Epoch 75/300
# 8/8 [==============================] - 0s 27ms/step - loss: 2.3719 - acc: 0.5302 - val_loss: 6.2632 - val_acc: 0.4000
# Epoch 76/300
# 8/8 [==============================] - 0s 26ms/step - loss: 2.3487 - acc: 0.5336 - val_loss: 6.4169 - val_acc: 0.4000
# Epoch 77/300
# 8/8 [==============================] - 0s 28ms/step - loss: 2.3287 - acc: 0.5379 - val_loss: 6.5376 - val_acc: 0.4000
# Epoch 78/300
# 8/8 [==============================] - 0s 26ms/step - loss: 2.3129 - acc: 0.5293 - val_loss: 6.4536 - val_acc: 0.4000
# Epoch 79/300
# 8/8 [==============================] - 0s 26ms/step - loss: 2.2878 - acc: 0.5422 - val_loss: 6.2276 - val_acc: 0.3966
# Epoch 80/300
# 8/8 [==============================] - 0s 27ms/step - loss: 2.2609 - acc: 0.5440 - val_loss: 6.2044 - val_acc: 0.3966
# Epoch 81/300
# 8/8 [==============================] - 0s 26ms/step - loss: 2.2404 - acc: 0.5440 - val_loss: 6.4238 - val_acc: 0.4000
# Epoch 82/300
# 8/8 [==============================] - 0s 28ms/step - loss: 2.2126 - acc: 0.5474 - val_loss: 6.6006 - val_acc: 0.4000
# Epoch 83/300
# 8/8 [==============================] - 0s 26ms/step - loss: 2.1880 - acc: 0.5578 - val_loss: 6.3883 - val_acc: 0.4000
# Epoch 84/300
# 8/8 [==============================] - 0s 31ms/step - loss: 2.1589 - acc: 0.5569 - val_loss: 6.3701 - val_acc: 0.3966
# Epoch 85/300
# 8/8 [==============================] - 0s 26ms/step - loss: 2.1347 - acc: 0.5672 - val_loss: 6.4696 - val_acc: 0.4000
# Epoch 86/300
# 8/8 [==============================] - 0s 27ms/step - loss: 2.1100 - acc: 0.5776 - val_loss: 6.4402 - val_acc: 0.4000
# Epoch 87/300
# 8/8 [==============================] - 0s 27ms/step - loss: 2.0835 - acc: 0.5845 - val_loss: 6.4659 - val_acc: 0.3966
# Epoch 88/300
# 8/8 [==============================] - 0s 28ms/step - loss: 2.0587 - acc: 0.5879 - val_loss: 6.5421 - val_acc: 0.4000
# Epoch 89/300
# 8/8 [==============================] - 0s 26ms/step - loss: 2.0324 - acc: 0.5991 - val_loss: 6.5745 - val_acc: 0.4000
# Epoch 90/300
# 8/8 [==============================] - 0s 28ms/step - loss: 2.0122 - acc: 0.6086 - val_loss: 6.3935 - val_acc: 0.3966
# Epoch 91/300
# 8/8 [==============================] - 0s 32ms/step - loss: 1.9878 - acc: 0.6112 - val_loss: 6.5167 - val_acc: 0.4000
# Epoch 92/300
# 8/8 [==============================] - 0s 27ms/step - loss: 1.9615 - acc: 0.6198 - val_loss: 6.5451 - val_acc: 0.4000
# Epoch 93/300
# 8/8 [==============================] - 0s 26ms/step - loss: 1.9389 - acc: 0.6250 - val_loss: 6.5743 - val_acc: 0.4000
# Epoch 94/300
# 8/8 [==============================] - 0s 26ms/step - loss: 1.9123 - acc: 0.6336 - val_loss: 6.6019 - val_acc: 0.4000
# Epoch 95/300
# 8/8 [==============================] - 0s 26ms/step - loss: 1.8870 - acc: 0.6526 - val_loss: 6.6006 - val_acc: 0.4000
# Epoch 96/300
# 8/8 [==============================] - 0s 27ms/step - loss: 1.8630 - acc: 0.6474 - val_loss: 6.5734 - val_acc: 0.3966
# Epoch 97/300
# 8/8 [==============================] - 0s 27ms/step - loss: 1.8373 - acc: 0.6612 - val_loss: 6.6490 - val_acc: 0.3966
# Epoch 98/300
# 8/8 [==============================] - 0s 26ms/step - loss: 1.8128 - acc: 0.6638 - val_loss: 6.6142 - val_acc: 0.3966
# Epoch 99/300
# 8/8 [==============================] - 0s 26ms/step - loss: 1.7877 - acc: 0.6845 - val_loss: 6.6998 - val_acc: 0.4000
# Epoch 100/300
# 8/8 [==============================] - 0s 28ms/step - loss: 1.7609 - acc: 0.6853 - val_loss: 6.6887 - val_acc: 0.3966
# Epoch 101/300
# 8/8 [==============================] - 0s 27ms/step - loss: 1.7375 - acc: 0.6966 - val_loss: 6.7133 - val_acc: 0.3966
# Epoch 102/300
# 8/8 [==============================] - 0s 27ms/step - loss: 1.7149 - acc: 0.7052 - val_loss: 6.6274 - val_acc: 0.3966
# Epoch 103/300
# 8/8 [==============================] - 0s 27ms/step - loss: 1.6937 - acc: 0.7172 - val_loss: 6.7196 - val_acc: 0.4000
# Epoch 104/300
# 8/8 [==============================] - 0s 26ms/step - loss: 1.6665 - acc: 0.7293 - val_loss: 6.7082 - val_acc: 0.3966
# Epoch 105/300
# 8/8 [==============================] - 0s 30ms/step - loss: 1.6421 - acc: 0.7371 - val_loss: 6.7213 - val_acc: 0.4000
# Epoch 106/300
# 8/8 [==============================] - 0s 27ms/step - loss: 1.6201 - acc: 0.7474 - val_loss: 6.7952 - val_acc: 0.4034
# Epoch 107/300
# 8/8 [==============================] - 0s 26ms/step - loss: 1.5971 - acc: 0.7466 - val_loss: 6.8231 - val_acc: 0.4103
# Epoch 108/300
# 8/8 [==============================] - 0s 28ms/step - loss: 1.5748 - acc: 0.7578 - val_loss: 6.7404 - val_acc: 0.3966
# Epoch 109/300
# 8/8 [==============================] - 0s 26ms/step - loss: 1.5542 - acc: 0.7517 - val_loss: 6.7222 - val_acc: 0.4000
# Epoch 110/300
# 8/8 [==============================] - 0s 29ms/step - loss: 1.5273 - acc: 0.7724 - val_loss: 6.8982 - val_acc: 0.4069
# Epoch 111/300
# 8/8 [==============================] - 0s 29ms/step - loss: 1.5048 - acc: 0.7802 - val_loss: 6.7546 - val_acc: 0.4034
# Epoch 112/300
# 8/8 [==============================] - 0s 28ms/step - loss: 1.4825 - acc: 0.7922 - val_loss: 6.8492 - val_acc: 0.4069
# Epoch 113/300
# 8/8 [==============================] - 0s 28ms/step - loss: 1.4571 - acc: 0.8043 - val_loss: 6.7941 - val_acc: 0.4034
# Epoch 114/300
# 8/8 [==============================] - 0s 28ms/step - loss: 1.4333 - acc: 0.8138 - val_loss: 6.9110 - val_acc: 0.4138
# Epoch 115/300
# 8/8 [==============================] - 0s 27ms/step - loss: 1.4113 - acc: 0.8181 - val_loss: 6.8164 - val_acc: 0.4034
# Epoch 116/300
# 8/8 [==============================] - 0s 26ms/step - loss: 1.3892 - acc: 0.8284 - val_loss: 6.8943 - val_acc: 0.4034
# Epoch 117/300
# 8/8 [==============================] - 0s 26ms/step - loss: 1.3667 - acc: 0.8310 - val_loss: 6.9117 - val_acc: 0.4069
# Epoch 118/300
# 8/8 [==============================] - 0s 26ms/step - loss: 1.3486 - acc: 0.8422 - val_loss: 6.9020 - val_acc: 0.4034
# Epoch 119/300
# 8/8 [==============================] - 0s 30ms/step - loss: 1.3268 - acc: 0.8457 - val_loss: 6.8814 - val_acc: 0.4034
# Epoch 120/300
# 8/8 [==============================] - 0s 28ms/step - loss: 1.3057 - acc: 0.8457 - val_loss: 6.9664 - val_acc: 0.4034
# Epoch 121/300
# 8/8 [==============================] - 0s 26ms/step - loss: 1.2833 - acc: 0.8603 - val_loss: 6.9584 - val_acc: 0.4069
# Epoch 122/300
# 8/8 [==============================] - 0s 28ms/step - loss: 1.2644 - acc: 0.8638 - val_loss: 6.8729 - val_acc: 0.4069
# Epoch 123/300
# 8/8 [==============================] - 0s 28ms/step - loss: 1.2426 - acc: 0.8655 - val_loss: 7.0267 - val_acc: 0.4069
# Epoch 124/300
# 8/8 [==============================] - 0s 26ms/step - loss: 1.2231 - acc: 0.8707 - val_loss: 6.9258 - val_acc: 0.4069
# Epoch 125/300
# 8/8 [==============================] - 0s 28ms/step - loss: 1.2062 - acc: 0.8672 - val_loss: 7.0251 - val_acc: 0.4103
# Epoch 126/300
# 8/8 [==============================] - 0s 26ms/step - loss: 1.1863 - acc: 0.8802 - val_loss: 6.9632 - val_acc: 0.4069
# Epoch 127/300
# 8/8 [==============================] - 0s 27ms/step - loss: 1.1687 - acc: 0.8828 - val_loss: 7.0103 - val_acc: 0.4103
# Epoch 128/300
# 8/8 [==============================] - 0s 27ms/step - loss: 1.1496 - acc: 0.8810 - val_loss: 6.9735 - val_acc: 0.4069
# Epoch 129/300
# 8/8 [==============================] - 0s 25ms/step - loss: 1.1292 - acc: 0.8897 - val_loss: 7.0097 - val_acc: 0.4103
# Epoch 130/300
# 8/8 [==============================] - 0s 27ms/step - loss: 1.1115 - acc: 0.8905 - val_loss: 7.0242 - val_acc: 0.4103
# Epoch 131/300
# 8/8 [==============================] - 0s 26ms/step - loss: 1.0945 - acc: 0.8948 - val_loss: 7.0304 - val_acc: 0.4138
# Epoch 132/300
# 8/8 [==============================] - 0s 68ms/step - loss: 1.0770 - acc: 0.8966 - val_loss: 7.0073 - val_acc: 0.4103
# Epoch 133/300
# 8/8 [==============================] - 0s 34ms/step - loss: 1.0581 - acc: 0.9017 - val_loss: 7.0767 - val_acc: 0.4138
# Epoch 134/300
# 8/8 [==============================] - 0s 26ms/step - loss: 1.0413 - acc: 0.9052 - val_loss: 7.0572 - val_acc: 0.4103
# Epoch 135/300
# 8/8 [==============================] - 0s 61ms/step - loss: 1.0237 - acc: 0.9112 - val_loss: 7.0705 - val_acc: 0.4103
# Epoch 136/300
# 8/8 [==============================] - 0s 47ms/step - loss: 1.0063 - acc: 0.9155 - val_loss: 7.0957 - val_acc: 0.4103
# Epoch 137/300
# 8/8 [==============================] - 0s 29ms/step - loss: 0.9897 - acc: 0.9147 - val_loss: 7.1091 - val_acc: 0.4103
# Epoch 138/300
# 8/8 [==============================] - 0s 30ms/step - loss: 0.9732 - acc: 0.9207 - val_loss: 7.1035 - val_acc: 0.4103
# Epoch 139/300
# 8/8 [==============================] - 0s 57ms/step - loss: 0.9559 - acc: 0.9216 - val_loss: 7.1048 - val_acc: 0.4103
# Epoch 140/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.9403 - acc: 0.9267 - val_loss: 7.1470 - val_acc: 0.4103
# Epoch 141/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.9265 - acc: 0.9284 - val_loss: 7.1165 - val_acc: 0.4103
# Epoch 142/300
# 8/8 [==============================] - 0s 29ms/step - loss: 0.9103 - acc: 0.9293 - val_loss: 7.1346 - val_acc: 0.4103
# Epoch 143/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.8942 - acc: 0.9319 - val_loss: 7.1616 - val_acc: 0.4103
# Epoch 144/300
# 8/8 [==============================] - 0s 29ms/step - loss: 0.8814 - acc: 0.9371 - val_loss: 7.1330 - val_acc: 0.4103
# Epoch 145/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.8681 - acc: 0.9388 - val_loss: 7.1535 - val_acc: 0.4103
# Epoch 146/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.8532 - acc: 0.9405 - val_loss: 7.2331 - val_acc: 0.4069
# Epoch 147/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.8389 - acc: 0.9414 - val_loss: 7.1446 - val_acc: 0.4069
# Epoch 148/300
# 8/8 [==============================] - 0s 30ms/step - loss: 0.8251 - acc: 0.9431 - val_loss: 7.2056 - val_acc: 0.4069
# Epoch 149/300
# 8/8 [==============================] - 0s 29ms/step - loss: 0.8127 - acc: 0.9440 - val_loss: 7.1958 - val_acc: 0.4069
# Epoch 150/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.8001 - acc: 0.9431 - val_loss: 7.2280 - val_acc: 0.4069
# Epoch 151/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.7853 - acc: 0.9422 - val_loss: 7.2137 - val_acc: 0.4069
# Epoch 152/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.7742 - acc: 0.9440 - val_loss: 7.2483 - val_acc: 0.4069
# Epoch 153/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.7623 - acc: 0.9379 - val_loss: 7.2119 - val_acc: 0.4069
# Epoch 154/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.7495 - acc: 0.9422 - val_loss: 7.2691 - val_acc: 0.4069
# Epoch 155/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.7366 - acc: 0.9466 - val_loss: 7.2257 - val_acc: 0.4069
# Epoch 156/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.7250 - acc: 0.9509 - val_loss: 7.2489 - val_acc: 0.4069
# Epoch 157/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.7138 - acc: 0.9483 - val_loss: 7.2568 - val_acc: 0.4069
# Epoch 158/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.7032 - acc: 0.9457 - val_loss: 7.2524 - val_acc: 0.4069
# Epoch 159/300
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6930 - acc: 0.9509 - val_loss: 7.3288 - val_acc: 0.4069
# Epoch 160/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6853 - acc: 0.9509 - val_loss: 7.2471 - val_acc: 0.4069
# Epoch 161/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6731 - acc: 0.9534 - val_loss: 7.3282 - val_acc: 0.4069
# Epoch 162/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6619 - acc: 0.9534 - val_loss: 7.2946 - val_acc: 0.4069
# Epoch 163/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6514 - acc: 0.9560 - val_loss: 7.2799 - val_acc: 0.4069
# Epoch 164/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6401 - acc: 0.9595 - val_loss: 7.3442 - val_acc: 0.4069
# Epoch 165/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6303 - acc: 0.9586 - val_loss: 7.3072 - val_acc: 0.4069
# Epoch 166/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6202 - acc: 0.9621 - val_loss: 7.3567 - val_acc: 0.4069
# Epoch 167/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6106 - acc: 0.9621 - val_loss: 7.3267 - val_acc: 0.4069
# Epoch 168/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6013 - acc: 0.9629 - val_loss: 7.3362 - val_acc: 0.4069
# Epoch 169/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5919 - acc: 0.9621 - val_loss: 7.3668 - val_acc: 0.4069
# Epoch 170/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.5829 - acc: 0.9621 - val_loss: 7.3273 - val_acc: 0.4069
# Epoch 171/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5750 - acc: 0.9621 - val_loss: 7.3871 - val_acc: 0.4069
# Epoch 172/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.5654 - acc: 0.9664 - val_loss: 7.3401 - val_acc: 0.4069
# Epoch 173/300
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5581 - acc: 0.9638 - val_loss: 7.3892 - val_acc: 0.4069
# Epoch 174/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.5488 - acc: 0.9655 - val_loss: 7.3887 - val_acc: 0.4069
# Epoch 175/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.5397 - acc: 0.9655 - val_loss: 7.4028 - val_acc: 0.4069
# Epoch 176/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.5330 - acc: 0.9664 - val_loss: 7.4008 - val_acc: 0.4069
# Epoch 177/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.5250 - acc: 0.9690 - val_loss: 7.3955 - val_acc: 0.4069
# Epoch 178/300
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5176 - acc: 0.9690 - val_loss: 7.4096 - val_acc: 0.4069
# Epoch 179/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.5105 - acc: 0.9698 - val_loss: 7.4123 - val_acc: 0.4069
# Epoch 180/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.5038 - acc: 0.9672 - val_loss: 7.4341 - val_acc: 0.4069
# Epoch 181/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4969 - acc: 0.9681 - val_loss: 7.4082 - val_acc: 0.4069
# Epoch 182/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4909 - acc: 0.9664 - val_loss: 7.4367 - val_acc: 0.4069
# Epoch 183/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4843 - acc: 0.9681 - val_loss: 7.4193 - val_acc: 0.4069
# Epoch 184/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4770 - acc: 0.9690 - val_loss: 7.4556 - val_acc: 0.4069
# Epoch 185/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4710 - acc: 0.9707 - val_loss: 7.4251 - val_acc: 0.4069
# Epoch 186/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4645 - acc: 0.9707 - val_loss: 7.4774 - val_acc: 0.4069
# Epoch 187/300
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4583 - acc: 0.9716 - val_loss: 7.4479 - val_acc: 0.4069
# Epoch 188/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4514 - acc: 0.9707 - val_loss: 7.4775 - val_acc: 0.4069
# Epoch 189/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4448 - acc: 0.9707 - val_loss: 7.4666 - val_acc: 0.4069
# Epoch 190/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4393 - acc: 0.9707 - val_loss: 7.5000 - val_acc: 0.4069
# Epoch 191/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4332 - acc: 0.9716 - val_loss: 7.4722 - val_acc: 0.4069
# Epoch 192/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4279 - acc: 0.9707 - val_loss: 7.5045 - val_acc: 0.4069
# Epoch 193/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4228 - acc: 0.9724 - val_loss: 7.4941 - val_acc: 0.4069
# Epoch 194/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4170 - acc: 0.9750 - val_loss: 7.5031 - val_acc: 0.4034
# Epoch 195/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4113 - acc: 0.9750 - val_loss: 7.5186 - val_acc: 0.4069
# Epoch 196/300
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4060 - acc: 0.9741 - val_loss: 7.5161 - val_acc: 0.4034
# Epoch 197/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4001 - acc: 0.9750 - val_loss: 7.5235 - val_acc: 0.4069
# Epoch 198/300
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3953 - acc: 0.9741 - val_loss: 7.5248 - val_acc: 0.4034
# Epoch 199/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3897 - acc: 0.9741 - val_loss: 7.5432 - val_acc: 0.4034
# Epoch 200/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3850 - acc: 0.9750 - val_loss: 7.5218 - val_acc: 0.4034
# Epoch 201/300
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3803 - acc: 0.9767 - val_loss: 7.5479 - val_acc: 0.4034
# Epoch 202/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3757 - acc: 0.9776 - val_loss: 7.5386 - val_acc: 0.4034
# Epoch 203/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3710 - acc: 0.9767 - val_loss: 7.5472 - val_acc: 0.4034
# Epoch 204/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3661 - acc: 0.9776 - val_loss: 7.5510 - val_acc: 0.4034
# Epoch 205/300
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3616 - acc: 0.9759 - val_loss: 7.5461 - val_acc: 0.4034
# Epoch 206/300
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3570 - acc: 0.9767 - val_loss: 7.5642 - val_acc: 0.4034
# Epoch 207/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3530 - acc: 0.9776 - val_loss: 7.5547 - val_acc: 0.4034
# Epoch 208/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3487 - acc: 0.9793 - val_loss: 7.5591 - val_acc: 0.4034
# Epoch 209/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3445 - acc: 0.9784 - val_loss: 7.5659 - val_acc: 0.4034
# Epoch 210/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3408 - acc: 0.9793 - val_loss: 7.5723 - val_acc: 0.4034
# Epoch 211/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3366 - acc: 0.9784 - val_loss: 7.5907 - val_acc: 0.4034
# Epoch 212/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3324 - acc: 0.9793 - val_loss: 7.5747 - val_acc: 0.4034
# Epoch 213/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3285 - acc: 0.9793 - val_loss: 7.5981 - val_acc: 0.4034
# Epoch 214/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3245 - acc: 0.9810 - val_loss: 7.5757 - val_acc: 0.4034
# Epoch 215/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3207 - acc: 0.9810 - val_loss: 7.6103 - val_acc: 0.4034
# Epoch 216/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3169 - acc: 0.9793 - val_loss: 7.5899 - val_acc: 0.4034
# Epoch 217/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3130 - acc: 0.9784 - val_loss: 7.6040 - val_acc: 0.4034
# Epoch 218/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3096 - acc: 0.9776 - val_loss: 7.6086 - val_acc: 0.4034
# Epoch 219/300
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3060 - acc: 0.9793 - val_loss: 7.6247 - val_acc: 0.4034
# Epoch 220/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3024 - acc: 0.9802 - val_loss: 7.6192 - val_acc: 0.4034
# Epoch 221/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2989 - acc: 0.9793 - val_loss: 7.6257 - val_acc: 0.4034
# Epoch 222/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.2956 - acc: 0.9810 - val_loss: 7.6066 - val_acc: 0.4000
# Epoch 223/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2923 - acc: 0.9802 - val_loss: 7.6325 - val_acc: 0.4034
# Epoch 224/300
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2895 - acc: 0.9810 - val_loss: 7.6365 - val_acc: 0.4034
# Epoch 225/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2859 - acc: 0.9810 - val_loss: 7.6565 - val_acc: 0.4034
# Epoch 226/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2827 - acc: 0.9845 - val_loss: 7.6512 - val_acc: 0.4034
# Epoch 227/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2794 - acc: 0.9836 - val_loss: 7.6694 - val_acc: 0.4034
# Epoch 228/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2766 - acc: 0.9845 - val_loss: 7.6536 - val_acc: 0.4000
# Epoch 229/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2743 - acc: 0.9819 - val_loss: 7.6819 - val_acc: 0.4034
# Epoch 230/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.2716 - acc: 0.9819 - val_loss: 7.6503 - val_acc: 0.4034
# Epoch 231/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2688 - acc: 0.9836 - val_loss: 7.6789 - val_acc: 0.4034
# Epoch 232/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2658 - acc: 0.9836 - val_loss: 7.6613 - val_acc: 0.4000
# Epoch 233/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2621 - acc: 0.9836 - val_loss: 7.6901 - val_acc: 0.4034
# Epoch 234/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2595 - acc: 0.9828 - val_loss: 7.6833 - val_acc: 0.4000
# Epoch 235/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2568 - acc: 0.9845 - val_loss: 7.6788 - val_acc: 0.4000
# Epoch 236/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2536 - acc: 0.9828 - val_loss: 7.6900 - val_acc: 0.4034
# Epoch 237/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2508 - acc: 0.9836 - val_loss: 7.6723 - val_acc: 0.4000
# Epoch 238/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2482 - acc: 0.9862 - val_loss: 7.7000 - val_acc: 0.4034
# Epoch 239/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2451 - acc: 0.9862 - val_loss: 7.7046 - val_acc: 0.4000
# Epoch 240/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2429 - acc: 0.9845 - val_loss: 7.6933 - val_acc: 0.4000
# Epoch 241/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.2404 - acc: 0.9853 - val_loss: 7.7071 - val_acc: 0.4000
# Epoch 242/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2376 - acc: 0.9853 - val_loss: 7.7074 - val_acc: 0.4000
# Epoch 243/300
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2351 - acc: 0.9862 - val_loss: 7.7097 - val_acc: 0.4034
# Epoch 244/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2328 - acc: 0.9879 - val_loss: 7.7215 - val_acc: 0.4034
# Epoch 245/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.2301 - acc: 0.9879 - val_loss: 7.7312 - val_acc: 0.4034
# Epoch 246/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.2279 - acc: 0.9853 - val_loss: 7.7303 - val_acc: 0.4000
# Epoch 247/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2255 - acc: 0.9845 - val_loss: 7.7397 - val_acc: 0.4000
# Epoch 248/300
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2231 - acc: 0.9845 - val_loss: 7.7414 - val_acc: 0.4034
# Epoch 249/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2209 - acc: 0.9845 - val_loss: 7.7380 - val_acc: 0.4000
# Epoch 250/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2185 - acc: 0.9845 - val_loss: 7.7488 - val_acc: 0.4000
# Epoch 251/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2163 - acc: 0.9853 - val_loss: 7.7515 - val_acc: 0.4000
# Epoch 252/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2143 - acc: 0.9871 - val_loss: 7.7573 - val_acc: 0.4000
# Epoch 253/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2118 - acc: 0.9897 - val_loss: 7.7573 - val_acc: 0.4000
# Epoch 254/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2099 - acc: 0.9897 - val_loss: 7.7641 - val_acc: 0.4000
# Epoch 255/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2080 - acc: 0.9905 - val_loss: 7.7722 - val_acc: 0.4000
# Epoch 256/300
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2061 - acc: 0.9905 - val_loss: 7.7766 - val_acc: 0.4000
# Epoch 257/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2039 - acc: 0.9871 - val_loss: 7.7764 - val_acc: 0.4000
# Epoch 258/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2018 - acc: 0.9888 - val_loss: 7.7829 - val_acc: 0.4000
# Epoch 259/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1998 - acc: 0.9888 - val_loss: 7.7872 - val_acc: 0.4000
# Epoch 260/300
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1978 - acc: 0.9897 - val_loss: 7.7943 - val_acc: 0.4000
# Epoch 261/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1969 - acc: 0.9871 - val_loss: 7.7820 - val_acc: 0.4000
# Epoch 262/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1960 - acc: 0.9862 - val_loss: 7.8286 - val_acc: 0.4034
# Epoch 263/300
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1940 - acc: 0.9871 - val_loss: 7.8342 - val_acc: 0.4034
# Epoch 264/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1915 - acc: 0.9871 - val_loss: 7.8189 - val_acc: 0.4034
# Epoch 265/300
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1893 - acc: 0.9897 - val_loss: 7.8125 - val_acc: 0.4034
# Epoch 266/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1878 - acc: 0.9897 - val_loss: 7.8123 - val_acc: 0.4034
# Epoch 267/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1859 - acc: 0.9922 - val_loss: 7.8216 - val_acc: 0.4000
# Epoch 268/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1844 - acc: 0.9914 - val_loss: 7.8333 - val_acc: 0.4034
# Epoch 269/300
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1824 - acc: 0.9905 - val_loss: 7.8339 - val_acc: 0.4034
# Epoch 270/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1804 - acc: 0.9922 - val_loss: 7.8127 - val_acc: 0.4000
# Epoch 271/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1787 - acc: 0.9914 - val_loss: 7.8350 - val_acc: 0.4034
# Epoch 272/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1769 - acc: 0.9905 - val_loss: 7.8408 - val_acc: 0.4034
# Epoch 273/300
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1754 - acc: 0.9922 - val_loss: 7.8401 - val_acc: 0.4034
# Epoch 274/300
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1736 - acc: 0.9922 - val_loss: 7.8436 - val_acc: 0.4034
# Epoch 275/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1723 - acc: 0.9922 - val_loss: 7.8553 - val_acc: 0.4034
# Epoch 276/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1709 - acc: 0.9905 - val_loss: 7.8471 - val_acc: 0.4000
# Epoch 277/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1691 - acc: 0.9897 - val_loss: 7.8510 - val_acc: 0.4000
# Epoch 278/300
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1675 - acc: 0.9914 - val_loss: 7.8524 - val_acc: 0.4034
# Epoch 279/300
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1661 - acc: 0.9905 - val_loss: 7.8575 - val_acc: 0.4000
# Epoch 280/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1641 - acc: 0.9914 - val_loss: 7.8635 - val_acc: 0.4000
# Epoch 281/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1633 - acc: 0.9922 - val_loss: 7.8603 - val_acc: 0.4000
# Epoch 282/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1616 - acc: 0.9914 - val_loss: 7.8630 - val_acc: 0.4000
# Epoch 283/300
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1602 - acc: 0.9914 - val_loss: 7.8751 - val_acc: 0.4000
# Epoch 284/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1589 - acc: 0.9922 - val_loss: 7.8695 - val_acc: 0.4000
# Epoch 285/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1575 - acc: 0.9914 - val_loss: 7.8778 - val_acc: 0.4000
# Epoch 286/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1564 - acc: 0.9914 - val_loss: 7.8848 - val_acc: 0.4000
# Epoch 287/300
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1545 - acc: 0.9922 - val_loss: 7.8679 - val_acc: 0.4000
# Epoch 288/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1533 - acc: 0.9922 - val_loss: 7.8725 - val_acc: 0.4000
# Epoch 289/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1518 - acc: 0.9931 - val_loss: 7.8838 - val_acc: 0.4000
# Epoch 290/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1506 - acc: 0.9922 - val_loss: 7.8758 - val_acc: 0.4000
# Epoch 291/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1493 - acc: 0.9914 - val_loss: 7.8787 - val_acc: 0.4000
# Epoch 292/300
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1481 - acc: 0.9905 - val_loss: 7.8845 - val_acc: 0.4000
# Epoch 293/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1468 - acc: 0.9914 - val_loss: 7.8876 - val_acc: 0.4000
# Epoch 294/300
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1454 - acc: 0.9922 - val_loss: 7.8857 - val_acc: 0.4000
# Epoch 295/300
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1444 - acc: 0.9922 - val_loss: 7.8959 - val_acc: 0.4000
# Epoch 296/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1429 - acc: 0.9922 - val_loss: 7.9042 - val_acc: 0.4000
# Epoch 297/300
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1418 - acc: 0.9931 - val_loss: 7.8972 - val_acc: 0.4000
# Epoch 298/300
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1407 - acc: 0.9922 - val_loss: 7.8990 - val_acc: 0.4000
# Epoch 299/300
# 8/8 [==============================] - 0s 35ms/step - loss: 0.1394 - acc: 0.9922 - val_loss: 7.9028 - val_acc: 0.4000
# Epoch 300/300
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1386 - acc: 0.9922 - val_loss: 7.9074 - val_acc: 0.4000

# %%
plt.plot(his.history['loss'], '-b', label='loss')
plt.plot(his.history['val_loss'], '-r', label='val_loss')
plt.legend()
plt.show()

plt.plot(his.history['acc'], '-b', label='acc')
plt.plot(his.history['val_acc'], '-r', label='val_acc')
plt.legend()
plt.show()

# %%
# 인코더
encoder_model = Model(encoder_inputs, encoder_states)

# 디코더 설계 시작
# 이전 시점의 상태를 보관할 텐서
decoder_state_input_h = Input(shape=(hidden_units,))
decoder_state_input_c = Input(shape=(hidden_units,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

# 훈련 때 사용했던 임베딩 층을 재사용
dec_emb2 = dec_emb_layer(decoder_inputs)

# 다음 단어 예측을 위해 이전 시점의 상태를 현 시점의 초기 상태로 사용
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=decoder_states_inputs)
decoder_states2 = [state_h2, state_c2]

# 모든 시점에 대해서 단어 예측
decoder_outputs2 = decoder_dense(decoder_outputs2)

# 수정된 디코더
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs2] + decoder_states2)

# %%
def decode_sequence(input_seq):
  # 입력으로부터 인코더의 마지막 시점의 상태(은닉 상태, 셀 상태)를 얻음
  states_value = encoder_model.predict(input_seq)

  # <SOS>에 해당하는 정수 생성
  target_seq = np.zeros((1,1))
  target_seq[0, 0] = targ_lang.word_index['<start>']

  stop_condition = False
  decoded_sentence = ''

  # stop_condition이 True가 될 때까지 루프 반복
  # 구현의 간소화를 위해서 이 함수는 배치 크기를 1로 가정합니다.
  while not stop_condition:
    # 이점 시점의 상태 states_value를 현 시점의 초기 상태로 사용
    output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

    # 예측 결과를 단어로 변환
    sampled_token_index = np.argmax(output_tokens[0, -1, :])
    sampled_char = targ_lang.index_word[sampled_token_index]

    # 현재 시점의 예측 단어를 예측 문장에 추가
    decoded_sentence += ' '+sampled_char

    # <eos>에 도달하거나 정해진 길이를 넘으면 중단.
    if (sampled_char == '<end>' or
        len(decoded_sentence) > 50):
        stop_condition = True

    # 현재 시점의 예측 결과를 다음 시점의 입력으로 사용하기 위해 저장
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = sampled_token_index

    # 현재 시점의 상태를 다음 시점의 상태로 사용하기 위해 저장
    states_value = [h, c]

  return decoded_sentence

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq_to_src(input_seq):
  sentence = ''
  for encoded_word in input_seq:
    if(encoded_word != 0):
      sentence = sentence + inp_lang.index_word[encoded_word] + ' '
  return sentence

# 번역문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq_to_tar(input_seq):
  sentence = ''
  for encoded_word in input_seq:
    if(encoded_word != 0):
      if (encoded_word != targ_lang.word_index['<start>']):
         if (encoded_word != targ_lang.word_index['<end>']):
           sentence = sentence + targ_lang.index_word[encoded_word] + ' '
  return sentence

# %%
for seq_index in [11, 22, 33, 44, 55]:
  input_seq = input_tensor_train[seq_index: seq_index + 1]
  decoded_sentence = decode_sequence(input_seq)

  print("입력문장 :",seq_to_src(input_tensor_train[seq_index]))
  print("정답문장 :",seq_to_tar(target_in_tensor_train[seq_index]))
  print("번역문장 :",decoded_sentence[1:-5])
  print("-"*50)
# Out:
# 입력문장 : 궁왕 대궐터희 오쟉이 지지괴니
# 정답문장 : 궁왕 대궐터에 까막까치가 지저귀니
# 번역문장 : 궁왕 대궐터에 까막까치가 지저귀니
# --------------------------------------------------
# 입력문장 : 금강ᄃᆡ ᄆᆡᆫ우층의 션학이 삿기치니
# 정답문장 : 금강대 맨 위층에 선학이 새끼치니
# 번역문장 : 금강대 맨 위층에 선학이 새끼치니
# --------------------------------------------------
# 입력문장 : 놉흘시고 망고ᄃᆡ 외로올샤 혈망봉이
# 정답문장 : 높을시고 망고대 외롭구나 혈망봉아
# 번역문장 : 높을시고 망고대 외롭구나 혈망봉아
# --------------------------------------------------
# 입력문장 : 이제와 보게되니 유정도 유정정ᄒᆞᆯ샤
# 정답문장 : 이제와 보게되니 유정도 유정하구나
# 번역문장 : 이제와 보게되니 유정도 유정하구나
# --------------------------------------------------
# 입력문장 : 풍운을 언제어더 삼일우ᄅᆞᆯ 디련ᄂᆞᆫ다
# 정답문장 : 풍운을 언제 얻어 삼일우를 내리려나
# 번역문장 : 풍운을 언제 얻어 삼일우를 내리려나
# --------------------------------------------------

# %%
for seq_index in [1, 7, 12, 15, 18]:
  input_seq = input_tensor_val[seq_index: seq_index + 1]
  decoded_sentence = decode_sequence(input_seq)

  print("입력문장 :",seq_to_src(input_tensor_val[seq_index]))
  print("정답문장 :",seq_to_tar(target_in_tensor_val[seq_index]))
  print("번역문장 :",decoded_sentence[1:-5])
  print("-"*50)
# Out:
# 입력문장 : 부상 지쳑의 명월을 기ᄃᆞ리니
# 정답문장 : 부상 가까이서 밝은 달을 기다리니
# 번역문장 : 연추문 달려들어 경회 남문 바라보며
# --------------------------------------------------
# 입력문장 : 뉴하쥬 ᄀᆞ득부어 ᄃᆞᆯᄃᆞ려 무론말이
# 정답문장 : 유하주 가득 부어 달더러 묻는 말이
# 번역문장 : 만이천봉을 역력히 헤아리니
# --------------------------------------------------
# 입력문장 : ᄭᅮᆷ애 ᄒᆞᆫ사ᄅᆞᆷ이 날ᄃᆞ려 닐온말이
# 정답문장 : 꿈에 한 사람이 날더러 이른 말이
# 번역문장 : 넓고 넓은 천하를 어찌하여 작단 말인가
# --------------------------------------------------
# 입력문장 : 인간의 내려와셔 우리ᄅᆞᆯ ᄯᆞᆯ오ᄂᆞᆫ다
# 정답문장 : 인간 세계에 내려와서 우리를 따르는가
# 번역문장 : 그 앞에 넓은 바위 화룡소가 되었구나
# --------------------------------------------------
# 입력문장 : 저먹고 날머겨놀 서너잔 거후로니
# 정답문장 : 저 먹고 날 먹이거늘 서너 잔 기울이니
# 번역문장 : 그 앞에 넓은 바위 화룡소가 되었구나
# --------------------------------------------------
